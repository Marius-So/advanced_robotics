# %%
import math

# %%
math.atan2(/)

# %%
# reference: https://realpython.com/python-opencv-color-spaces/

# imports 
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb
import time
import apriltag

import os

# %%
images = []
img_folder = 'orientation_test'
for file in os.listdir(img_folder)[:2]:
    image = cv2.imread(os.path.join(img_folder, file))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #my_picture_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    plt.imshow(image)

# %%
image.shape
# Out:
# (3024, 4032)

# %%
img = image
scale_percent = 20 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)

# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
print(resized.shape)


detector = apriltag.Detector()
result = detector.detect(resized)

print(result)
# Out:
# (604, 806)
# [Detection(tag_family=b'tag36h11', tag_id=0, hamming=0, goodness=0.0, decision_margin=75.517578125, homography=array([[-4.41214996e-01, -1.95587553e-01, -1.75515448e+01],
#        [ 1.34064985e-01, -8.57461782e-01, -1.09061337e+01],
#        [ 6.76981555e-04, -6.11319494e-04, -4.64886459e-02]]), center=array([377.54476435, 234.59779274]), corners=array([[363.33355713, 218.72813416],
#        [393.73974609, 219.34803772],
#        [391.7961731 , 250.51234436],
#        [362.22317505, 249.02513123]])), Detection(tag_family=b'tag36h11', tag_id=1, hamming=0, goodness=0.0, decision_margin=82.8254623413086, homography=array([[-4.66935495e-01, -4.62590034e-02, -2.50379761e+01],
#        [ 9.18213369e-02, -7.23673851e-01, -1.02885394e+01],
#        [ 4.34649752e-04, -1.37854835e-04, -4.28434036e-02]]), center=array([584.40679218, 240.14290417]), corners=array([[568.49023438, 223.84428406],
#        [602.27374268, 224.10321045],
#        [600.54541016, 256.66891479],
# ...

# %%
result
# Out:
# [Detection(tag_family=b'tag36h11', tag_id=0, hamming=0, goodness=0.0, decision_margin=75.517578125, homography=array([[-4.41214996e-01, -1.95587553e-01, -1.75515448e+01],
#         [ 1.34064985e-01, -8.57461782e-01, -1.09061337e+01],
#         [ 6.76981555e-04, -6.11319494e-04, -4.64886459e-02]]), center=array([377.54476435, 234.59779274]), corners=array([[363.33355713, 218.72813416],
#         [393.73974609, 219.34803772],
#         [391.7961731 , 250.51234436],
#         [362.22317505, 249.02513123]])),
#  Detection(tag_family=b'tag36h11', tag_id=1, hamming=0, goodness=0.0, decision_margin=82.8254623413086, homography=array([[-4.66935495e-01, -4.62590034e-02, -2.50379761e+01],
#         [ 9.18213369e-02, -7.23673851e-01, -1.02885394e+01],
#         [ 4.34649752e-04, -1.37854835e-04, -4.28434036e-02]]), center=array([584.40679218, 240.14290417]), corners=array([[568.49023438, 223.84428406],
#         [602.27374268, 224.10321045],
#         [600.54541016, 256.66891479],
# ...

# %%
print(result[0].homography)
x = 1
r32 = result[x].homography[2][1]
r33 = result[x].homography[2][1]

print(math.atan2(r32,r33))
# Out:
# [[-4.41214996e-01 -1.95587553e-01 -1.75515448e+01]
#  [ 1.34064985e-01 -8.57461782e-01 -1.09061337e+01]
#  [ 6.76981555e-04 -6.11319494e-04 -4.64886459e-02]]
# -2.356194490192345

# %%
print(plt.imshow(resized))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
image_2 = cv2.imread('example_image.png')
image_2 = cv2.cvtColor(image_2, cv2.COLOR_BGR2GRAY)

plt.imshow(image_2, cmap='gray')

# %%
result_2 = detector.detect(image_2)

# %%
result_2
# Out:
# []
